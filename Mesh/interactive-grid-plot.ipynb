# %%
import os
import uxarray as ux
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime
from cartopy.mpl.ticker import LatitudeFormatter, LongitudeFormatter
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0e0b55e9-83d3-46a2-81c2-84ff8192780b'>
#   <div id="e2d9cdf0-ca31-4b8f-a3fe-ad469285b498" data-root-id="0e0b55e9-83d3-46a2-81c2-84ff8192780b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
uxgrid = ux.open_grid('derecho-EXODUS.g', engine='netcdf4')
lc = uxgrid.to_linecollection(colors="black", linewidths=0.25)

fig, ax = plt.subplots(1,
                       1,
                       figsize=(10, 10),
                       constrained_layout=True,
                       subplot_kw={"projection": ccrs.PlateCarree()}
                      )

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_collection(lc)
ax.set_extent((-125, -60, 25, 65), crs=ccrs.PlateCarree())
gl = ax.gridlines(draw_labels=True)
gl.xlines = False
gl.ylines = False
ax.set_title("Derecho EXODUS Mesh")
# Out:
# Text(0.5, 1.0, 'Derecho EXODUS Mesh')

# %%
uxgrid = ux.open_grid('derecho-EXODUS.g', engine='netcdf4')
lc = uxgrid.to_linecollection(colors="black", linewidths=0.25)

fig, ax = plt.subplots(1,
                       1,
                       figsize=(10, 10),
                       constrained_layout=True,
                       subplot_kw={"projection": ccrs.PlateCarree()}
                      )

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_collection(lc)
ax.set_extent((-100, -90, 40, 50), crs=ccrs.PlateCarree())
gl = ax.gridlines(draw_labels=True)
gl.xlines = False
gl.ylines = False
ax.set_title("Derecho EXODUS Mesh")
# Out:
# Text(0.5, 1.0, 'Derecho EXODUS Mesh')

# %%
uxgrid_smoother = ux.open_grid('/glade/u/home/nforcone/CESM-Meeting/Mesh/Smoother-Transition/derecho-Smoother-Improved-EXODUS.g', engine='netcdf4')
lc_smoother = uxgrid_smoother.to_linecollection(colors="black", linewidths=0.25)

fig, ax = plt.subplots(1,
                       1,
                       figsize=(10, 10),
                       constrained_layout=True,
                       subplot_kw={"projection": ccrs.PlateCarree()}
                      )

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_collection(lc_smoother)
ax.set_extent((-125, -60, 25, 65), crs=ccrs.PlateCarree())
gl = ax.gridlines(draw_labels=True)
gl.xlines = False
gl.ylines = False
ax.set_title("Derecho EXODUS Mesh")
# Out:
# Text(0.5, 1.0, 'Derecho EXODUS Mesh')

# %%
uxgrid_smoother = ux.open_grid('/glade/u/home/nforcone/CESM-Meeting/Mesh/Smoother-Transition/derecho-Smoother-Improved-EXODUS.g', engine='netcdf4')
lc_smoother = uxgrid_smoother.to_linecollection(colors="black", linewidths=0.25)

fig, ax = plt.subplots(1,
                       1,
                       figsize=(10, 10),
                       constrained_layout=True,
                       subplot_kw={"projection": ccrs.PlateCarree()}
                      )

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_collection(lc_smoother)
ax.set_global()
gl = ax.gridlines(draw_labels=True)
gl.xlines = False
gl.ylines = False
ax.set_title("Derecho EXODUS Mesh")
# Out:
# Text(0.5, 1.0, 'Derecho EXODUS Mesh')

# %%
uxgrid_smoother = ux.open_grid('/glade/u/home/nforcone/CESM-Meeting/Mesh/Smoother-Transition/derecho-Smoother-Improved-EXODUS.g', engine='netcdf4')
lc_smoother = uxgrid_smoother.to_linecollection(colors="black", linewidths=0.25)

fig, ax = plt.subplots(1,
                       1,
                       figsize=(10, 10),
                       constrained_layout=True,
                       subplot_kw={"projection": ccrs.PlateCarree()}
                      )

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_collection(lc_smoother)
ax.set_extent((-105, -78, 35, 48), crs=ccrs.PlateCarree())
gl = ax.gridlines(draw_labels=True)
gl.xlines = False
gl.ylines = False
ax.set_title("Derecho EXODUS Mesh")
# Out:
# Text(0.5, 1.0, 'Derecho EXODUS Mesh')
